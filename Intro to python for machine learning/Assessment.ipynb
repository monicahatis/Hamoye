# %%
import pandas as pd

# %%
df=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# ##### Given the following python code, what would the output of the code give?
#
# my_tuppy = (1,2,5,8)
#
# my_tuppy[2] = 6

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [191], in <cell line: 1>()
# ----> 1 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ##### Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
df2 = df[['Y2017', 'Area']]

# %%
df2
# Out:
#           Y2017      Area
# 0      41389.00   Algeria
# 1          0.00   Algeria
# 2       3341.00   Algeria
# 3         92.82   Algeria
# 4         80.19   Algeria
# ...         ...       ...
# 60938     19.00  Zimbabwe
# 60939      1.33  Zimbabwe
# 60940      1.00  Zimbabwe
# 60941      0.04  Zimbabwe
# 60942      0.02  Zimbabwe
#
# [60943 rows x 2 columns]

# %%
df3 = df.groupby(['Area'], sort=True)['Y2017'].sum()

# %%
df3.sort_values( ascending=True, inplace=True)

# %%
df3
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
df3.head(7).tail(1)
# Out:
# Area
# Guinea-Bissau    19102.77
# Name: Y2017, dtype: float64

# %% [markdown]
# ##### How would you check for the number of rows and columns in a pandas DataFrame named df?

# %%
df.shape
# Out:
# (60943, 12)

# %% [markdown]
# ##### Given the following numpy array
#
# array  = ([[94, 89, 63],
#
#              [93, 92, 48],
#
#              [92, 94, 56]])
#
# ##### How would you select  the elements in bold and italics from the array?

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array[1 : , : ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [200], in <cell line: 1>()
# ----> 1 array[1 : , : ]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
array[ : 2, 1 : ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [201], in <cell line: 1>()
# ----> 1 array[ : 2, 1 : ]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
array[ : 1, 1 : ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [202], in <cell line: 1>()
# ----> 1 array[ : 1, 1 : ]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
array[ : 1, 1 :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [203], in <cell line: 1>()
# ----> 1 array[ : 1, 1 :]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
array[ : 2, 0 : ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [204], in <cell line: 1>()
# ----> 1 array[ : 2, 0 : ]
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# ##### Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
df4 = df.groupby(['Element']).sum()

# %%
df4
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
df4.loc['Stock Variation']
# Out:
# Area Code         571566.00
# Item Code       11329527.00
# Element Code    21464704.00
# Y2014              58749.83
# Y2015              34910.99
# Y2016              33140.12
# Y2017              54316.91
# Y2018              20577.91
# Name: Stock Variation, dtype: float64

# %% [markdown]
# ##### Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
df4
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
df_2017 = df4['Y2017']

# %%
df_2017
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
df_2017.loc['Processing']
# Out:
# 292836.0

# %% [markdown]
# ##### What would be the output for?
#
# S = [['him', 'sell'], [90, 28, 43]]
#
# S[0][1][1]

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# ##### Which year had the least correlation with ‘Element Code’?

# %%
correlated = df.corr()
correlated
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
corr_years = correlated.drop(correlated.columns[[0,1,2]], axis=1)
corr_years
# Out:
#                  Y2014     Y2015     Y2016     Y2017     Y2018
# Area Code     0.006164  0.005472  0.005247  0.005006  0.005665
# Item Code     0.021722  0.020857  0.020109  0.021494  0.021314
# Element Code  0.024457  0.023889  0.023444  0.024254  0.024279
# Y2014         1.000000  0.994647  0.996081  0.995230  0.994872
# Y2015         0.994647  1.000000  0.995739  0.988048  0.988208
# Y2016         0.996081  0.995739  1.000000  0.992785  0.992757
# Y2017         0.995230  0.988048  0.992785  1.000000  0.998103
# Y2018         0.994872  0.988208  0.992757  0.998103  1.000000

# %%
least_value_column = corr_years.loc['Element Code'].idxmin()
least_value_column
# Out:
# 'Y2016'

# %% [markdown]
# ##### Answer the following questions based on the African food production dataset provided by the FAO website already provided
#
# ##### What is the total sum of Wine produced in 2015 and 2018 respectively?
#
# Hint:
#
# Perform a groupby sum aggregation on ‘Item’

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df_item = df.groupby(['Item']).sum()
df_item
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
df2015_18 = df_item.drop(correlated.columns[[0,1,2,3,5,6]], axis=1)
df2015_18
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
df2015_18.loc['Wine']
# Out:
# Y2015    4251.81
# Y2018    4039.32
# Name: Wine, dtype: float64

# %% [markdown]
# ##### What is the total number of unique countries in the dataset?

# %%
total_unique_countries = df['Area'].nunique()

# %%
total_unique_countries
# Out:
# 49

# %% [markdown]
# ##### What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
DF_2017 = df['Y2017']

# %%
DF_2017
# Out:
# 0        41389.00
# 1            0.00
# 2         3341.00
# 3           92.82
# 4           80.19
#            ...
# 60938       19.00
# 60939        1.33
# 60940        1.00
# 60941        0.04
# 60942        0.02
# Name: Y2017, Length: 60943, dtype: float64

# %%
mean_2017 = DF_2017.mean()

# %%
"{:.2f}".format(mean_2017)
# Out:
# '140.92'

# %%
std_2017 = DF_2017.std()

# %%
"{:.2f}".format(std_2017)
# Out:
# '1671.86'

# %% [markdown]
# ##### What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
DF_2014 = df['Y2014']
DF_2014
# Out:
# 0        38924.00
# 1            0.00
# 2         3377.00
# 3           94.90
# 4           80.06
#            ...
# 60938       42.00
# 60939        3.06
# 60940        3.00
# 60941        0.10
# 60942        0.04
# Name: Y2014, Length: 60943, dtype: float64

# %%
missing_data = DF_2014.isnull().sum()
missing_data
# Out:
# 1589

# %%
total_values = DF_2014.size
total_values
# Out:
# 60943

# %%
percent_missing = (total_missing / total_values) * 100
percent_missing.round(3)
# Out:
# 2.607

# %% [markdown]
# ##### Consider the following list of tuples:
#
# y = [(2, 4), (7, 8), (1, 5, 9)]
#
# ##### How would you assign element 8 from the list to a variable x?

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x = y[1][1]
x
# Out:
# 8

# %% [markdown]
# ##### If you have the following list
#
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
#
# col = [‘Age’,’Nationality’,’Overall’]
#
# ##### How do you create a pandas DataFrame using this list, to look like the table below?

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

# %%
pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# ##### What is the total Protein supply quantity in Madagascar in 2015?

# %%
Area_elem2015 = df.iloc[:, [1,5,8]]
Area_elem2015
# Out:
#            Area                                 Element     Y2015
# 0       Algeria           Total Population - Both sexes  39728.00
# 1       Algeria                Domestic supply quantity      0.00
# 2       Algeria           Food supply (kcal/capita/day)   3379.00
# 3       Algeria  Protein supply quantity (g/capita/day)     94.35
# 4       Algeria      Fat supply quantity (g/capita/day)     79.36
# ...         ...                                     ...       ...
# 60938  Zimbabwe                                    Food     46.00
# 60939  Zimbabwe     Food supply quantity (kg/capita/yr)      3.33
# 60940  Zimbabwe           Food supply (kcal/capita/day)      4.00
# 60941  Zimbabwe  Protein supply quantity (g/capita/day)      0.11
# 60942  Zimbabwe      Fat supply quantity (g/capita/day)      0.05
#
# [60943 rows x 3 columns]

# %%
total_protein_supply_2015_madagascar = Area_elem2015.query('Area == "Madagascar" and Element == "Protein supply quantity (g/capita/day)"').sum()
total_protein_supply_2015_madagascar
# Out:
# Area       MadagascarMadagascarMadagascarMadagascarMadaga...
# Element    Protein supply quantity (g/capita/day)Protein ...
# Y2015                                                 173.05
# dtype: object

# %% [markdown]
# ##### Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
grouped_df = df_2017.groupby(['Area']).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [238], in <cell line: 1>()
# ----> 1 grouped_df = df_2017.groupby(['Area']).sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1720, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1717     raise TypeError("You have to supply one of 'by' and 'level'")
#    1718 axis = self._get_axis_number(axis)
# -> 1720 return SeriesGroupBy(
#    1721     obj=self,
#    1722     keys=by,
#    1723     axis=axis,
#    1724     level=level,
#    1725     as_index=as_index,
#    1726     sort=sort,
#    1727     group_keys=group_keys,
#    1728     squeeze=squeeze,
#    1729     observed=observed,
#    1730     dropna=dropna,
#    1731 )
#
# ...

# %%
grouped_df2
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# C�te d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
highest_sum_area = grouped_df2['Y2017'].idxmax()

# %%
highest_sum_area
# Out:
# 'Nigeria'
